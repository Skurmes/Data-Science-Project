# %%
print(5)
# Out:
# 5

# %%
import pandas as pd

# %%
print(pd._version_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7fdd43cd8eca> in <module>
# ----> 1 print(pd._version_)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute '_version_'

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.2.4

# %%
pd.read_json("coin_Bitcoin_1.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-267b01a2d4a3> in <module>
# ----> 1 pd.read_json("coin_Bitcoin_1.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
import csv

with open('coin_Bitcoin[1].csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
       print(row)
# Out:
# ['SNo', 'Name', 'Symbol', 'Date', 'High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap']
# ['1', 'Bitcoin', 'BTC', '2013-04-29 23:59:59', '147.48800659179688', '134.0', '134.44400024414062', '144.5399932861328', '0.0', '1603768864.5']
# ['2', 'Bitcoin', 'BTC', '2013-04-30 23:59:59', '146.92999267578125', '134.0500030517578', '144.0', '139.0', '0.0', '1542813125.0']
# ['3', 'Bitcoin', 'BTC', '2013-05-01 23:59:59', '139.88999938964844', '107.72000122070312', '139.0', '116.98999786376953', '0.0', '1298954593.75']
# ['4', 'Bitcoin', 'BTC', '2013-05-02 23:59:59', '125.5999984741211', '92.28189849853516', '116.37999725341797', '105.20999908447266', '0.0', '1168517495.25']
# ['5', 'Bitcoin', 'BTC', '2013-05-03 23:59:59', '108.12799835205078', '79.0999984741211', '106.25', '97.75', '0.0', '1085995168.75']
# ['6', 'Bitcoin', 'BTC', '2013-05-04 23:59:59', '115.0', '92.5', '98.0999984741211', '112.5', '0.0', '1250316562.5']
# ...

# %%
df = ('coin_Bitcoin[1].csv')

df.shape('High')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-a690bf97ec0c> in <module>
#       1 df = ('coin_Bitcoin[1].csv')
#       2
# ----> 3 df.shape('High')
#
# AttributeError: 'str' object has no attribute 'shape'

# %%
stat,
p = df
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-cc14e90507d7> in <module>
# ----> 1 stat,
#       2 p = df
#       3 print('stat=%.3f, p=%.3f' % (stat, p))
#       4 if p > 0.05:
#       5         print('Probably Gaussian')
#
# NameError: name 'stat' is not defined

# %%
from scipy.stats
stat, p = df
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')
# Out:
#   File "<ipython-input-20-3f112896704d>", line 1
#     from scipy.stats
#                     ^
# SyntaxError: invalid syntax

# %%
from scipy.stats import shapiro
stat, p = shapiro(df)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-152fa526c466> in <module>
#       1 from scipy.stats import shapiro
# ----> 2 stat, p = shapiro(df)
#       3 print('stat=%.3f, p=%.3f' % (stat, p))
#       4 if p > 0.05:
#       5         print('Probably Gaussian')
#
# ~\anaconda3\lib\site-packages\scipy\stats\morestats.py in shapiro(x)
#    1668     N = len(x)
#    1669     if N < 3:
# -> 1670         raise ValueError("Data must be at least length 3.")
#    1671
#    1672     a = zeros(N, 'f')
#
# ValueError: Data must be at least length 3.

# %%
sample_data = pd.read_csv('coin_Bitcoin[1].csv')

# %%
sample_data
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2857  2858  Bitcoin    BTC  2021-02-23 23:59:59  54204.929756  45290.590268
# 2858  2859  Bitcoin    BTC  2021-02-24 23:59:59  51290.136695  47213.498162
# 2859  2860  Bitcoin    BTC  2021-02-25 23:59:59  51948.966982  47093.853019
# 2860  2861  Bitcoin    BTC  2021-02-26 23:59:59  48370.785260  44454.842114
# 2861  2862  Bitcoin    BTC  2021-02-27 23:59:59  48253.270101  45269.025766
#
# ...

# %%
sample_data.High
# Out:
# 0         147.488007
# 1         146.929993
# 2         139.889999
# 3         125.599998
# 4         108.127998
#             ...
# 2857    54204.929756
# 2858    51290.136695
# 2859    51948.966982
# 2860    48370.785260
# 2861    48253.270101
# Name: High, Length: 2862, dtype: float64

# %%
plt.plot(sample_data.Date,sample_data.High)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-587ccf2d3e94> in <module>
# ----> 1 plt.plot(sample_data.Date,sample_data.High)
#       2 plt.show
#
# NameError: name 'plt' is not defined

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(sample_data.SNo,sample_data.High)
plt.show ()

# %%
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f503e9c6cf11> in <module>
# ----> 1 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
from fbprophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df = sample_data
df = df[[sample_data.Date,sample_data.Close]]
df.columns = ["ds", "y"]
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e78ecccd3072> in <module>
# ----> 1 df = sample_data
#       2 df = df[[sample_data.Date,sample_data.Close]]
#       3 df.columns = ["ds", "y"]
#       4 print(df)
#
# NameError: name 'sample_data' is not defined

# %%
import csv

with open('coin_Bitcoin[1].csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
       print(row)
# Out:
# ['SNo', 'Name', 'Symbol', 'Date', 'High', 'Low', 'Open', 'Close', 'Volume', 'Marketcap']
# ['1', 'Bitcoin', 'BTC', '2013-04-29 23:59:59', '147.48800659179688', '134.0', '134.44400024414062', '144.5399932861328', '0.0', '1603768864.5']
# ['2', 'Bitcoin', 'BTC', '2013-04-30 23:59:59', '146.92999267578125', '134.0500030517578', '144.0', '139.0', '0.0', '1542813125.0']
# ['3', 'Bitcoin', 'BTC', '2013-05-01 23:59:59', '139.88999938964844', '107.72000122070312', '139.0', '116.98999786376953', '0.0', '1298954593.75']
# ['4', 'Bitcoin', 'BTC', '2013-05-02 23:59:59', '125.5999984741211', '92.28189849853516', '116.37999725341797', '105.20999908447266', '0.0', '1168517495.25']
# ['5', 'Bitcoin', 'BTC', '2013-05-03 23:59:59', '108.12799835205078', '79.0999984741211', '106.25', '97.75', '0.0', '1085995168.75']
# ['6', 'Bitcoin', 'BTC', '2013-05-04 23:59:59', '115.0', '92.5', '98.0999984741211', '112.5', '0.0', '1250316562.5']
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv
# 3224 2022-02-25 23:59:59  36583.926578  31262.540473  41832.311840
# 3225 2022-02-26 23:59:59  36410.315037  30953.943984  41598.822624
# 3226 2022-02-27 23:59:59  36133.922292  31162.928407  41200.092614
#
# [1000 rows x 4 columns]

# %%
future = prophet.make_future_dataframe(periods=365)
print(future)
# Out:
#                       ds
# 0    2013-04-29 23:59:59
# 1    2013-04-30 23:59:59
# 2    2013-05-01 23:59:59
# 3    2013-05-02 23:59:59
# 4    2013-05-03 23:59:59
# ...                  ...
# 3222 2022-02-23 23:59:59
# 3223 2022-02-24 23:59:59
# 3224 2022-02-25 23:59:59
# 3225 2022-02-26 23:59:59
# 3226 2022-02-27 23:59:59
#
# [3227 rows x 1 columns]

# %%
forecast = prophet.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(10)
# Out:
#                       ds          yhat    yhat_lower    yhat_upper
# 3217 2022-02-18 23:59:59  37238.341267  32122.478389  42333.770612
# 3218 2022-02-19 23:59:59  37245.343692  32080.485300  42310.665940
# 3219 2022-02-20 23:59:59  37137.155199  32128.848886  42389.141698
# 3220 2022-02-21 23:59:59  37089.780774  32064.790780  42721.436963
# 3221 2022-02-22 23:59:59  36981.373636  31414.449034  42194.878111
# 3222 2022-02-23 23:59:59  36883.250875  31905.348526  41942.174341
# 3223 2022-02-24 23:59:59  36731.813474  31750.138413  41980.355113
# 3224 2022-02-25 23:59:59  36583.926578  31310.564540  42091.528542
# 3225 2022-02-26 23:59:59  36410.315037  31163.124415  41752.573136
# 3226 2022-02-27 23:59:59  36133.922292  30749.502200  41120.043542

# %%
from fbprophet.plot import plot
prophet.plot(forecast, figsize=(20, 10))

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
forecast = prophet.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(200)
range (3217,3226)
# Out:
# range(3217, 3226)

# %%
df = pd.read_csv('coin_Bitcoin[1].csv')
df = df[["Date", "Volume" ,"Close"]]
df.columns = ["ds", "y" , "x"]
print(df)
# Out:
#                        ds             y             x
# 0     2013-04-29 23:59:59  0.000000e+00    144.539993
# 1     2013-04-30 23:59:59  0.000000e+00    139.000000
# 2     2013-05-01 23:59:59  0.000000e+00    116.989998
# 3     2013-05-02 23:59:59  0.000000e+00    105.209999
# 4     2013-05-03 23:59:59  0.000000e+00     97.750000
# ...                   ...           ...           ...
# 2857  2021-02-23 23:59:59  1.061025e+11  48824.426869
# 2858  2021-02-24 23:59:59  6.369552e+10  49705.333316
# 2859  2021-02-25 23:59:59  5.450657e+10  47093.853019
# 2860  2021-02-26 23:59:59  3.509679e+11  46339.760083
# 2861  2021-02-27 23:59:59  4.591095e+10  46188.451275
#
# [2862 rows x 3 columns]

# %%
prophet = Prophet()
prophet.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = prophet.make_future_dataframe(periods=365)
print(future)
# Out:
#                       ds
# 0    2013-04-29 23:59:59
# 1    2013-04-30 23:59:59
# 2    2013-05-01 23:59:59
# 3    2013-05-02 23:59:59
# 4    2013-05-03 23:59:59
# ...                  ...
# 3222 2022-02-23 23:59:59
# 3223 2022-02-24 23:59:59
# 3224 2022-02-25 23:59:59
# 3225 2022-02-26 23:59:59
# 3226 2022-02-27 23:59:59
#
# [3227 rows x 1 columns]

# %%
forecast = prophet.predict(future)
forecast["ds", "y"].tail(1000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('ds', 'y')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-0c8a7f92e846> in <module>
# ...
